# %% [markdown]
# # Nen Voting

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
def expFunc(x):
  return 2 - math.exp(-0.3*(x/10))

# %%
x=np.arange(0.1,90)
y=[expFunc(x) for x in x]
plt.plot(x,y)
